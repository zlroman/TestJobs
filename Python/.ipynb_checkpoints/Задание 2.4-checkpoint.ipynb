# %%
user_ids = []
with open( 'data.txt', 'r' ) as f:
    for line in f:
        user_id =  line.strip() 
        user_ids.append( user_id )

# %%
user_ids[0:5]
# Out:
# ['1010', '1036', '1041', '1041', '1042']

# %%
len(user_ids)
# Out:
# 294

# %%
list_of_zeros_and_ones = [ 0, 1, 0, 1, 0, 1 ]
print( set( list_of_zeros_and_ones ) )
# Out:
# {0, 1}

# %%
unique_ids = set( user_ids )

# %%
print( 'Уникальных ID в файле data.txt - {}'.format( len( unique_ids ) ) )
# Out:
# Уникальных ID в файле data.txt - 18

# %%
with open( 'user_ids_headers.txt', 'r' ) as f:
    for line in f:
        print( line.strip() )
# Out:
# user_id
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# 1243
# 1243
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1248
# 1248
# 1252
# 1252
# 1253
# 1253
# 1258
# 1258
# 1263
# 1263
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1268
# 1268
# 1269
# 1270
# 1273
# 1273
# 1274
# 1278
# 1278
# 1279
# 1281
# 1283
# 1283
# 1288
# 1288
# 1291
# 1293
# 1293
# 1294
# 1296
# 1298
# 1298
# 1298
# 1300
# 1300
# 1302
# 1303
# 1303
# 1308
# 1308
# 1313
# 1313
# 1315
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %% [markdown]
# Какая строчка появится первой при чтении файла user_ids_headers.txt
# описанным выше способом?

# %% [markdown]
# user_id

# %%
Started = True
with open( 'user_ids_headers.txt', 'r' ) as f:
    for line in f:
        # запись "if Started" эквивалентна "if Started == True"
        if Started:
            # эта строчка выполняется один раз только на первом шаге цикла
            Started = False
        else:
            # эту строчку выполняем со второго и во всех следующих шагах цикла
            print( line.strip() )
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# 1243
# 1243
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1248
# 1248
# 1252
# 1252
# 1253
# 1253
# 1258
# 1258
# 1263
# 1263
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1268
# 1268
# 1269
# 1270
# 1273
# 1273
# 1274
# 1278
# 1278
# 1279
# 1281
# 1283
# 1283
# 1288
# 1288
# 1291
# 1293
# 1293
# 1294
# 1296
# 1298
# 1298
# 1298
# 1300
# 1300
# 1302
# 1303
# 1303
# 1308
# 1308
# 1313
# 1313
# 1315
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %%
with open( 'data_3_columns.txt', 'r' ) as f:
    for line in f:
        print( line.strip() )
# Out:
# seo	google	20,20
# sem	yandex	15,60
# email	promo	13,20
# sem	yandex	9,80
# sem	google	14,80
# sem	google	14,40
# sem	google	14,00
# brand	yandex	20,00
# sem	yandex	16,20
# email	promo	11,00
# cpa-partners	burgerclub	10,80
# seo	google	22,60
# seo	google	22,40
# sem	yandex	24,40
# seo	google	16,60
# sem	yandex	8,60
# seo	yandex	12,40
# cpa-partners	food-delivery	16,20
# email	promo	24,00
# sem	yandex	18,80
# email	promo	11,80
# sem	google	9,40
# sem	google	11,20
# email	promo	19,00
# sem	google	23,40
# cpc-partners	city-magazine	17,00
# seo	google	20,80
# email	promo	15,60
# cpc-partners	foody	22,40
# seo	yandex	15,60
# cpa-partners	food-delivery	21,00
# seo	google	22,40
# sem	google	20,40
# email	promo	26,00
# seo	yandex	18,40
# email	promo	14,60
# seo	yandex	29,80
# email	promo	20,00
# sem	google	19,00
# brand	google	16,40
# sem	yandex	16,20
# sem	yandex	17,80
# email	promo	18,80
# cpa-partners	burgerclub	20,00
# seo	google	21,00
# seo	yandex	16,60
# email	promo	20,00
# sem	yandex	19,80
# email	promo	16,80
# cpa-partners	food-delivery	24,00
# sem	yandex	12,00
# sem	yandex	10,20
# email	promo	24,00
# sem	yandex	15,80
# sem	yandex	22,00
# sem	google	17,40
# sem	yandex	14,80
# email	promo	20,00
# brand	yandex	11,60
# seo	yandex	20,00
# sem	yandex	16,00
# seo	yandex	11,20
# seo	google	12,20
# sem	yandex	19,20
# sem	google	17,80
# sem	google	19,80
# email	promo	8,60
# email	promo	28,60
# email	newsletter	18,80
# sem	google	17,60
# email	promo	16,00
# cpa-partners	food-delivery	15,40
# sem	yandex	21,60
# email	promo	7,60
# brand	yandex	21,60
# smm	facebook	17,40
# sem	google	22,00
# email	promo	22,00
# email	promo	16,00
# seo	yandex	16,00
# sem	yandex	20,00
# email	promo	10,00
# sem	yandex	21,20
# seo	yandex	30,40
# cpa-partners	burgerclub	18,80
# sem	yandex	14,00
# email	promo	22,00
# sem	google	16,00
# sem	yandex	12,60
# sem	google	13,40
# seo	yandex	13,60
# sem	yandex	10,20
# brand	yandex	17,40
# sem	google	22,40
# sem	yandex	11,40
# sem	google	14,00
# seo	yandex	22,40
# sem	yandex	18,00
# brand	direct	17,00
# cpa-partners	food-delivery	24,80
# brand	google	16,60
# sem	google	17,80
# sem	google	9,00
# email	promo	10,60
# brand	google	23,40
# cpa-partners	burgerclub	21,00
# email	promo	16,60
# cpc-partners	foody	24,20
# seo	google	20,40
# seo	yandex	25,60
# brand	yandex	19,80
# smm	facebook	16,40
# email	promo	16,20
# seo	yandex	17,00
# email	promo	16,80
# sem	yandex	19,80
# seo	yandex	15,60
# email	newsletter	19,20
# sem	google	23,20
# sem	yandex	10,80
# sem	google	24,40
# sem	yandex	13,40
# seo	yandex	12,00
# smm	facebook	18,60
# sem	google	16,60
# cpa-partners	burgerclub	12,20
# cpa-partners	burgerclub	22,40
# seo	google	15,40
# cpc-partners	city-magazine	17,20
# cpa-partners	burgerclub	17,60
# email	promo	16,40
# email	promo	18,60
# email	promo	19,80
# brand	google	18,80
# seo	google	17,60
# email	promo	20,60
# cpa-partners	food-delivery	15,00
# sem	yandex	22,00
# email	promo	17,40
# seo	yandex	13,60
# seo	yandex	17,60
# email	promo	18,40
# email	promo	20,40
# sem	yandex	20,00
# brand	yandex	17,80
# seo	google	16,00
# email	promo	14,60
# email	promo	17,20
# sem	yandex	13,60
# email	promo	23,60
# sem	google	15,60
# sem	yandex	21,40
# sem	google	13,00
# seo	yandex	18,60
# cpa-partners	burgerclub	20,60
# seo	yandex	11,40
# email	promo	18,00
# smm	vk	12,00
# sem	yandex	16,00
# sem	google	12,20
# brand	direct	23,00
# sem	yandex	24,00
# email	promo	11,80
# email	newsletter	17,20
# email	newsletter	24,60
# sem	yandex	30,40
# sem	yandex	18,00
# email	promo	15,00
# sem	google	13,20
# seo	yandex	28,80
# sem	yandex	22,00
# email	promo	15,60
# sem	yandex	13,60
# sem	google	8,60
# sem	google	22,00
# email	promo	20,00
# sem	yandex	12,60
# sem	google	18,00
# brand	direct	11,00
# email	promo	12,20
# sem	yandex	18,00
# email	promo	12,40
# seo	google	13,00
# brand	direct	21,40
# sem	yandex	13,60
# cpa-partners	food-delivery	17,40
# sem	google	15,00
# seo	yandex	14,40
# brand	direct	16,00
# seo	yandex	12,00
# sem	yandex	12,80
# email	promo	21,40
# sem	yandex	17,40
# sem	yandex	21,60
# email	promo	16,00
# sem	google	16,40
# sem	yandex	16,00
# email	promo	22,00
# brand	yandex	21,80
# email	promo	14,60
# seo	yandex	22,00
# email	promo	25,00
# sem	google	15,60
# email	promo	17,80
# sem	yandex	14,80
# sem	yandex	18,20
# sem	google	12,60
# email	promo	11,80
# sem	yandex	16,00
# seo	yandex	30,40
# seo	google	13,40
# email	newsletter	18,40
# email	promo	20,00
# smm	vk	17,00
# sem	google	26,00
# sem	google	21,00
# cpc-partners	foody	19,40
# sem	yandex	16,00
# sem	yandex	12,80
# sem	google	14,00
# cpa-partners	burgerclub	21,80
# cpc-partners	city-magazine	11,80
# sem	google	25,80
# sem	google	18,00
# sem	google	10,20
# email	promo	12,00
# sem	google	13,80
# sem	google	16,60
# sem	google	11,40
# brand	google	13,40
# sem	yandex	14,00
# sem	google	16,60
# email	promo	24,00
# email	promo	10,20
# email	promo	18,60
# sem	yandex	21,60
# cpa-partners	burgerclub	20,20
# sem	yandex	18,00
# email	promo	17,40
# email	promo	22,00
# sem	yandex	17,40
# sem	yandex	19,00
# smm	facebook	18,00
# brand	google	16,00
# email	promo	28,60
# sem	yandex	18,40
# email	promo	18,80
# seo	yandex	17,80
# sem	yandex	16,80
# sem	yandex	19,40
# sem	google	20,00
# sem	yandex	16,00
# sem	google	22,00
# cpa-partners	food-delivery	12,80
# email	promo	20,00
# sem	yandex	17,40
# email	promo	15,60
# sem	google	22,00
# sem	google	14,40
# sem	google	12,20
# seo	yandex	12,20
# email	promo	20,00
# cpa-partners	food-delivery	13,00
# sem	yandex	22,40
# sem	yandex	13,60
# sem	google	30,40
# sem	yandex	12,40
# sem	yandex	16,00
# seo	yandex	30,40
# cpc-partners	city-magazine	23,20
# sem	google	20,00
# email	promo	12,60
# sem	google	14,60
# cpc-partners	city-magazine	11,80
# smm	facebook	20,20
# sem	google	10,00
# email	promo	12,80
# sem	yandex	20,60
# seo	yandex	18,00
# cpa-partners	food-delivery	13,80
# seo	yandex	12,80
# sem	yandex	17,20
# sem	google	16,00
# email	promo	14,20
# sem	yandex	19,60
# seo	google	22,40
# email	promo	14,80
# sem	google	13,00
# sem	google	13,60
# email	promo	12,60
# seo	yandex	19,20
# email	promo	20,20
# sem	google	16,00
# sem	yandex	11,60

# %%
with open( 'data_3_columns.txt', 'r' ) as f:
    for line in f:
        line = line.strip().split('\t')
        print( line )
# Out:
# ['seo', 'google', '20,20']
# ['sem', 'yandex', '15,60']
# ['email', 'promo', '13,20']
# ['sem', 'yandex', '9,80']
# ['sem', 'google', '14,80']
# ['sem', 'google', '14,40']
# ['sem', 'google', '14,00']
# ['brand', 'yandex', '20,00']
# ['sem', 'yandex', '16,20']
# ['email', 'promo', '11,00']
# ['cpa-partners', 'burgerclub', '10,80']
# ['seo', 'google', '22,60']
# ['seo', 'google', '22,40']
# ['sem', 'yandex', '24,40']
# ['seo', 'google', '16,60']
# ['sem', 'yandex', '8,60']
# ['seo', 'yandex', '12,40']
# ['cpa-partners', 'food-delivery', '16,20']
# ['email', 'promo', '24,00']
# ['sem', 'yandex', '18,80']
# ['email', 'promo', '11,80']
# ['sem', 'google', '9,40']
# ['sem', 'google', '11,20']
# ['email', 'promo', '19,00']
# ['sem', 'google', '23,40']
# ['cpc-partners', 'city-magazine', '17,00']
# ['seo', 'google', '20,80']
# ['email', 'promo', '15,60']
# ['cpc-partners', 'foody', '22,40']
# ['seo', 'yandex', '15,60']
# ['cpa-partners', 'food-delivery', '21,00']
# ['seo', 'google', '22,40']
# ['sem', 'google', '20,40']
# ['email', 'promo', '26,00']
# ['seo', 'yandex', '18,40']
# ['email', 'promo', '14,60']
# ['seo', 'yandex', '29,80']
# ['email', 'promo', '20,00']
# ['sem', 'google', '19,00']
# ['brand', 'google', '16,40']
# ['sem', 'yandex', '16,20']
# ['sem', 'yandex', '17,80']
# ['email', 'promo', '18,80']
# ['cpa-partners', 'burgerclub', '20,00']
# ['seo', 'google', '21,00']
# ['seo', 'yandex', '16,60']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '19,80']
# ['email', 'promo', '16,80']
# ['cpa-partners', 'food-delivery', '24,00']
# ['sem', 'yandex', '12,00']
# ['sem', 'yandex', '10,20']
# ['email', 'promo', '24,00']
# ['sem', 'yandex', '15,80']
# ['sem', 'yandex', '22,00']
# ['sem', 'google', '17,40']
# ['sem', 'yandex', '14,80']
# ['email', 'promo', '20,00']
# ['brand', 'yandex', '11,60']
# ['seo', 'yandex', '20,00']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '11,20']
# ['seo', 'google', '12,20']
# ['sem', 'yandex', '19,20']
# ['sem', 'google', '17,80']
# ['sem', 'google', '19,80']
# ['email', 'promo', '8,60']
# ['email', 'promo', '28,60']
# ['email', 'newsletter', '18,80']
# ['sem', 'google', '17,60']
# ['email', 'promo', '16,00']
# ['cpa-partners', 'food-delivery', '15,40']
# ['sem', 'yandex', '21,60']
# ['email', 'promo', '7,60']
# ['brand', 'yandex', '21,60']
# ['smm', 'facebook', '17,40']
# ['sem', 'google', '22,00']
# ['email', 'promo', '22,00']
# ['email', 'promo', '16,00']
# ['seo', 'yandex', '16,00']
# ['sem', 'yandex', '20,00']
# ['email', 'promo', '10,00']
# ['sem', 'yandex', '21,20']
# ['seo', 'yandex', '30,40']
# ['cpa-partners', 'burgerclub', '18,80']
# ['sem', 'yandex', '14,00']
# ['email', 'promo', '22,00']
# ['sem', 'google', '16,00']
# ['sem', 'yandex', '12,60']
# ['sem', 'google', '13,40']
# ['seo', 'yandex', '13,60']
# ['sem', 'yandex', '10,20']
# ['brand', 'yandex', '17,40']
# ['sem', 'google', '22,40']
# ['sem', 'yandex', '11,40']
# ['sem', 'google', '14,00']
# ['seo', 'yandex', '22,40']
# ['sem', 'yandex', '18,00']
# ['brand', 'direct', '17,00']
# ['cpa-partners', 'food-delivery', '24,80']
# ['brand', 'google', '16,60']
# ['sem', 'google', '17,80']
# ['sem', 'google', '9,00']
# ['email', 'promo', '10,60']
# ['brand', 'google', '23,40']
# ['cpa-partners', 'burgerclub', '21,00']
# ['email', 'promo', '16,60']
# ['cpc-partners', 'foody', '24,20']
# ['seo', 'google', '20,40']
# ['seo', 'yandex', '25,60']
# ['brand', 'yandex', '19,80']
# ['smm', 'facebook', '16,40']
# ['email', 'promo', '16,20']
# ['seo', 'yandex', '17,00']
# ['email', 'promo', '16,80']
# ['sem', 'yandex', '19,80']
# ['seo', 'yandex', '15,60']
# ['email', 'newsletter', '19,20']
# ['sem', 'google', '23,20']
# ['sem', 'yandex', '10,80']
# ['sem', 'google', '24,40']
# ['sem', 'yandex', '13,40']
# ['seo', 'yandex', '12,00']
# ['smm', 'facebook', '18,60']
# ['sem', 'google', '16,60']
# ['cpa-partners', 'burgerclub', '12,20']
# ['cpa-partners', 'burgerclub', '22,40']
# ['seo', 'google', '15,40']
# ['cpc-partners', 'city-magazine', '17,20']
# ['cpa-partners', 'burgerclub', '17,60']
# ['email', 'promo', '16,40']
# ['email', 'promo', '18,60']
# ['email', 'promo', '19,80']
# ['brand', 'google', '18,80']
# ['seo', 'google', '17,60']
# ['email', 'promo', '20,60']
# ['cpa-partners', 'food-delivery', '15,00']
# ['sem', 'yandex', '22,00']
# ['email', 'promo', '17,40']
# ['seo', 'yandex', '13,60']
# ['seo', 'yandex', '17,60']
# ['email', 'promo', '18,40']
# ['email', 'promo', '20,40']
# ['sem', 'yandex', '20,00']
# ['brand', 'yandex', '17,80']
# ['seo', 'google', '16,00']
# ['email', 'promo', '14,60']
# ['email', 'promo', '17,20']
# ['sem', 'yandex', '13,60']
# ['email', 'promo', '23,60']
# ['sem', 'google', '15,60']
# ['sem', 'yandex', '21,40']
# ['sem', 'google', '13,00']
# ['seo', 'yandex', '18,60']
# ['cpa-partners', 'burgerclub', '20,60']
# ['seo', 'yandex', '11,40']
# ['email', 'promo', '18,00']
# ['smm', 'vk', '12,00']
# ['sem', 'yandex', '16,00']
# ['sem', 'google', '12,20']
# ['brand', 'direct', '23,00']
# ['sem', 'yandex', '24,00']
# ['email', 'promo', '11,80']
# ['email', 'newsletter', '17,20']
# ['email', 'newsletter', '24,60']
# ['sem', 'yandex', '30,40']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '15,00']
# ['sem', 'google', '13,20']
# ['seo', 'yandex', '28,80']
# ['sem', 'yandex', '22,00']
# ['email', 'promo', '15,60']
# ['sem', 'yandex', '13,60']
# ['sem', 'google', '8,60']
# ['sem', 'google', '22,00']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '12,60']
# ['sem', 'google', '18,00']
# ['brand', 'direct', '11,00']
# ['email', 'promo', '12,20']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '12,40']
# ['seo', 'google', '13,00']
# ['brand', 'direct', '21,40']
# ['sem', 'yandex', '13,60']
# ['cpa-partners', 'food-delivery', '17,40']
# ['sem', 'google', '15,00']
# ['seo', 'yandex', '14,40']
# ['brand', 'direct', '16,00']
# ['seo', 'yandex', '12,00']
# ['sem', 'yandex', '12,80']
# ['email', 'promo', '21,40']
# ['sem', 'yandex', '17,40']
# ['sem', 'yandex', '21,60']
# ['email', 'promo', '16,00']
# ['sem', 'google', '16,40']
# ['sem', 'yandex', '16,00']
# ['email', 'promo', '22,00']
# ['brand', 'yandex', '21,80']
# ['email', 'promo', '14,60']
# ['seo', 'yandex', '22,00']
# ['email', 'promo', '25,00']
# ['sem', 'google', '15,60']
# ['email', 'promo', '17,80']
# ['sem', 'yandex', '14,80']
# ['sem', 'yandex', '18,20']
# ['sem', 'google', '12,60']
# ['email', 'promo', '11,80']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '30,40']
# ['seo', 'google', '13,40']
# ['email', 'newsletter', '18,40']
# ['email', 'promo', '20,00']
# ['smm', 'vk', '17,00']
# ['sem', 'google', '26,00']
# ['sem', 'google', '21,00']
# ['cpc-partners', 'foody', '19,40']
# ['sem', 'yandex', '16,00']
# ['sem', 'yandex', '12,80']
# ['sem', 'google', '14,00']
# ['cpa-partners', 'burgerclub', '21,80']
# ['cpc-partners', 'city-magazine', '11,80']
# ['sem', 'google', '25,80']
# ['sem', 'google', '18,00']
# ['sem', 'google', '10,20']
# ['email', 'promo', '12,00']
# ['sem', 'google', '13,80']
# ['sem', 'google', '16,60']
# ['sem', 'google', '11,40']
# ['brand', 'google', '13,40']
# ['sem', 'yandex', '14,00']
# ['sem', 'google', '16,60']
# ['email', 'promo', '24,00']
# ['email', 'promo', '10,20']
# ['email', 'promo', '18,60']
# ['sem', 'yandex', '21,60']
# ['cpa-partners', 'burgerclub', '20,20']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '17,40']
# ['email', 'promo', '22,00']
# ['sem', 'yandex', '17,40']
# ['sem', 'yandex', '19,00']
# ['smm', 'facebook', '18,00']
# ['brand', 'google', '16,00']
# ['email', 'promo', '28,60']
# ['sem', 'yandex', '18,40']
# ['email', 'promo', '18,80']
# ['seo', 'yandex', '17,80']
# ['sem', 'yandex', '16,80']
# ['sem', 'yandex', '19,40']
# ['sem', 'google', '20,00']
# ['sem', 'yandex', '16,00']
# ['sem', 'google', '22,00']
# ['cpa-partners', 'food-delivery', '12,80']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '17,40']
# ['email', 'promo', '15,60']
# ['sem', 'google', '22,00']
# ['sem', 'google', '14,40']
# ['sem', 'google', '12,20']
# ['seo', 'yandex', '12,20']
# ['email', 'promo', '20,00']
# ['cpa-partners', 'food-delivery', '13,00']
# ['sem', 'yandex', '22,40']
# ['sem', 'yandex', '13,60']
# ['sem', 'google', '30,40']
# ['sem', 'yandex', '12,40']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '30,40']
# ['cpc-partners', 'city-magazine', '23,20']
# ['sem', 'google', '20,00']
# ['email', 'promo', '12,60']
# ['sem', 'google', '14,60']
# ['cpc-partners', 'city-magazine', '11,80']
# ['smm', 'facebook', '20,20']
# ['sem', 'google', '10,00']
# ['email', 'promo', '12,80']
# ['sem', 'yandex', '20,60']
# ['seo', 'yandex', '18,00']
# ['cpa-partners', 'food-delivery', '13,80']
# ['seo', 'yandex', '12,80']
# ['sem', 'yandex', '17,20']
# ['sem', 'google', '16,00']
# ['email', 'promo', '14,20']
# ['sem', 'yandex', '19,60']
# ['seo', 'google', '22,40']
# ['email', 'promo', '14,80']
# ['sem', 'google', '13,00']
# ['sem', 'google', '13,60']
# ['email', 'promo', '12,60']
# ['seo', 'yandex', '19,20']
# ['email', 'promo', '20,20']
# ['sem', 'google', '16,00']
# ['sem', 'yandex', '11,60']

# %%
total_sum = 0
with open( 'data_3_columns.txt', 'r' ) as f:
    for line in f:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',', '.'))
        if source == 'yandex' and medium == 'seo':
            total_sum += amount_paid
            print( 'Текущая сумма расходов yandex для seo: {:.2f}'.format( total_sum ) )
# Out:
# Текущая сумма расходов yandex для seo: 12.40
# Текущая сумма расходов yandex для seo: 28.00
# Текущая сумма расходов yandex для seo: 46.40
# Текущая сумма расходов yandex для seo: 76.20
# Текущая сумма расходов yandex для seo: 92.80
# Текущая сумма расходов yandex для seo: 112.80
# Текущая сумма расходов yandex для seo: 124.00
# Текущая сумма расходов yandex для seo: 140.00
# Текущая сумма расходов yandex для seo: 170.40
# Текущая сумма расходов yandex для seo: 184.00
# Текущая сумма расходов yandex для seo: 206.40
# Текущая сумма расходов yandex для seo: 232.00
# Текущая сумма расходов yandex для seo: 249.00
# Текущая сумма расходов yandex для seo: 264.60
# Текущая сумма расходов yandex для seo: 276.60
# Текущая сумма расходов yandex для seo: 290.20
# Текущая сумма расходов yandex для seo: 307.80
# Текущая сумма расходов yandex для seo: 326.40
# Текущая сумма расходов yandex для seo: 337.80
# Текущая сумма расходов yandex для seo: 366.60
# Текущая сумма расходов yandex для seo: 381.00
# Текущая сумма расходов yandex для seo: 393.00
# Текущая сумма расходов yandex для seo: 415.00
# Текущая сумма расходов yandex для seo: 445.40
# Текущая сумма расходов yandex для seo: 463.20
# Текущая сумма расходов yandex для seo: 475.40
# Текущая сумма расходов yandex для seo: 505.80
# Текущая сумма расходов yandex для seo: 523.80
# Текущая сумма расходов yandex для seo: 536.60
# Текущая сумма расходов yandex для seo: 555.80

# %%
import openpyxl

# %%
workbook = 'data.xlsx'
sheetName = 'data'

# %%
wb = openpyxl.load_workbook( workbook )
sheet = wb[sheetName]

# %%
sheet
# Out:
# <Worksheet "data">

# %%
for line in sheet[ 'A1:I1' ]:
    print( line )
# Out:
# (<Cell 'data'.A1>, <Cell 'data'.B1>, <Cell 'data'.C1>, <Cell 'data'.D1>, <Cell 'data'.E1>, <Cell 'data'.F1>, <Cell 'data'.G1>, <Cell 'data'.H1>, <Cell 'data'.I1>)

# %%
print("e1 =", line[4].value)
# Out:
# e1 = medium

# %%
for line in sheet[ 'E2:I5' ]:
    medium = line[0].value
    source = line[1].value
    amount_paid = line[4].value
    print( source, medium, amount_paid )
# Out:
# google seo 20.2
# yandex sem 15.6
# promo email 13.2
# yandex sem 9.8

# %%
type(amount_paid)
# Out:
# float

# %%
total_amount_paid = 0
for line in sheet[ 'E2:I295' ]:
    amount_paid = line[4].value
    total_amount_paid += amount_paid

total_amount_paid
# Out:
# 5129.8
